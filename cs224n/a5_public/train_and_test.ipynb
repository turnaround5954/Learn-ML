# %%
# !git clone https://github.com/turnaround5954/homework.git
# Out:
# Cloning into 'homework'...
# remote: Enumerating objects: 67, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 67 (delta 10), reused 42 (delta 5), pack-reused 0
# Unpacking objects: 100% (67/67), done.

# %%
# %cd homework/cs224n/a5_public/
# Out:
# /kaggle/working/homework/cs224n/a5_public

# %%
# !sh run.sh vocab
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# read in source sentences: ./en_es_data/train_tiny.es
# read in target sentences: ./en_es_data/train_tiny.en
# initialize source vocabulary ..
# number of word types: 129, number of word types w/ frequency >= 1: 129
# initialize target vocabulary ..
# number of word types: 130, number of word types w/ frequency >= 1: 130
# generated vocabulary, source 133 words, target 132 words
# vocabulary saved to vocab_tiny_q1.json
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# read in source sentences: ./en_es_data/train_tiny.es
# read in target sentences: ./en_es_data/train_tiny.en
# initialize source vocabulary ..
# number of word types: 129, number of word types w/ frequency >= 2: 29
# initialize target vocabulary ..
# number of word types: 130, number of word types w/ frequency >= 2: 37
# ...

# %%
# !sh run.sh train
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# uniformly initialize parameters [-0.100000, +0.100000]
# use device: cuda:0
# begin Maximum Likelihood training
# epoch 1, iter 10, avg. loss 563.41, avg. ppl 3647605466187.90 cum. examples 320, speed 4753.24 words/sec, time elapsed 1.31 sec
# epoch 1, iter 20, avg. loss 459.18, avg. ppl 4776152374.40 cum. examples 640, speed 5823.27 words/sec, time elapsed 2.44 sec
# epoch 1, iter 30, avg. loss 454.44, avg. ppl 1388100691.36 cum. examples 960, speed 5184.71 words/sec, time elapsed 3.78 sec
# epoch 1, iter 40, avg. loss 427.64, avg. ppl 1329230473.72 cum. examples 1280, speed 5592.28 words/sec, time elapsed 4.94 sec
# epoch 1, iter 50, avg. loss 430.38, avg. ppl 893627826.75 cum. examples 1600, speed 6083.08 words/sec, time elapsed 6.04 sec
# epoch 1, iter 60, avg. loss 411.76, avg. ppl 531973576.33 cum. examples 1920, speed 5919.80 words/sec, time elapsed 7.15 sec
# ...

# %%
# !sh run.sh test
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# load test source sentences from [./en_es_data/test.es]
# load test target sentences from [./en_es_data/test.en]
# load model from model.bin
# ...
# Decoding: 100%|█████████████████████████████| 8064/8064 [08:45<00:00, 15.35it/s]
# Corpus BLEU: 36.260917989579575
